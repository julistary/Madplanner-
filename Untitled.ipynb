# %%
import pandas as pd
import os
import json
import requests
from dotenv import load_dotenv
import time
import src.google_places as gp

# %%
lista = ["japones"]

# %%
japones = gp.gp_call("japones")

# %%
japones["results"]
# Out:
# [{'business_status': 'OPERATIONAL',
#   'formatted_address': 'Paseo de la Chopera, 194, 28100 Alcobendas, Madrid, Spain',
#   'geometry': {'location': {'lat': 40.5453363, 'lng': -3.658872999999999},
#    'viewport': {'northeast': {'lat': 40.54661797989272,
#      'lng': -3.657528520107278},
#     'southwest': {'lat': 40.54391832010727, 'lng': -3.660228179892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'name': 'Sakura Mini Asia',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 700,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115722590167649477966">A Google User</a>'],
#     'photo_reference': 'ATtYBwLeEIBDnD73qrfQi9lFG8LqbyRxhv-FJGolyYf4suv4yOqQyxtapNtQDXZA87n-G4UiBHDaoFUPOEen4GmCVHW_joEO9KPa1FrkSqpA_T7SvWwZwdyqvIwbCuVOEQD2Kfn4cgwk3p24Ge4ocPYSuTGqQYLFt28T1g-RNmvq-dfCHOEH',
#     'width': 1242}],
#   'place_id': 'ChIJs_paPoMsQg0RS9FfOiER6C4',
#   'plus_code': {'compound_code': 'G8WR+4F Alcobendas',
#    'global_code': '8CGRG8WR+4F'},
#   'rating': 3.8,
#   'reference': 'ChIJs_paPoMsQg0RS9FfOiER6C4',
#   'types': ['meal_delivery',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'user_ratings_total': 50},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Carr. de Fuencarral, 9A, 28108 Alcobendas, Madrid, Spain',
#   'geometry': {'location': {'lat': 40.5269693, 'lng': -3.6510759},
#    'viewport': {'northeast': {'lat': 40.52840122989272,
#      'lng': -3.649410820107277},
#     'southwest': {'lat': 40.52570157010728, 'lng': -3.652110479892721}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'name': 'Shikku Market',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 1528,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101172559635485758622">A Google User</a>'],
#     'photo_reference': 'ATtYBwI-qmA7mOfaJDKSaAhQjqzMFMUtrtBkqznAEf5BmAB8c--qF_X5bzNNbkz9RvkzEdroAupJypypvi5J7jHavKy7orQUXGI46YqA-5O6Frptg_mgvvRAo7Vl-lnota5S7lJtjmUmIbz_KyMrQq1f1-wRHoCcEvfs2UXABTQ1yMgoncPR',
#     'width': 3520}],
#   'place_id': 'ChIJcyGYXmUsQg0RvMXgot_fYkM',
#   'plus_code': {'compound_code': 'G8GX+QH Alcobendas',
#    'global_code': '8CGRG8GX+QH'},
#   'rating': 3.9,
#   'reference': 'ChIJcyGYXmUsQg0RvMXgot_fYkM',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 170},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Calle de Fco. Largo Caballero, 26, 28100 Alcobendas, Madrid, Spain',
#   'geometry': {'location': {'lat': 40.5537, 'lng': -3.650408},
#    'viewport': {'northeast': {'lat': 40.55499297989272,
#      'lng': -3.649061570107278},
#     'southwest': {'lat': 40.55229332010728, 'lng': -3.651761229892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'name': 'Restaurante Wenga',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 2448,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105464626352692146515">Restaurante Wenga</a>'],
#     'photo_reference': 'ATtYBwJoah6qNAc4HWhGF5lDKaGR72vz1Iy5patsu_HlVA9RrwbJjxKMyJb1xV5Lj8SpBHUiTyFwIToeXUL29BdUZkFfHdV9WOnUsH3tbfLn-iKt1m5xQh1SYl37nDFJ0DCqmmFdDTXEU4aDz6I1qkYJfVMUiXQu5BiZTixU-2lubeCWe0mf',
#     'width': 3264}],
#   'place_id': 'ChIJj6nDcZcsQg0R5T3qq5-6-Q0',
#   'plus_code': {'compound_code': 'H83X+FR Alcobendas',
#    'global_code': '8CGRH83X+FR'},
#   'price_level': 1,
#   'rating': 3.8,
#   'reference': 'ChIJj6nDcZcsQg0R5T3qq5-6-Q0',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 252},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Paseo de la Chopera, 64, 28100 Alcobendas, Madrid, Spain',
#   'geometry': {'location': {'lat': 40.541645, 'lng': -3.641038},
#    'viewport': {'northeast': {'lat': 40.54289707989273,
#      'lng': -3.639842120107277},
#     'southwest': {'lat': 40.54019742010728, 'lng': -3.642541779892721}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'name': 'MR.SUSHI',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 2976,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116902364470149399458">A Google User</a>'],
#     'photo_reference': 'ATtYBwKGnLSubBqe7gsG8iIGXJ5Ij3n5nJrueBKA8sc8RRHgv8gqcPCD7imlFo-EZ1Gw3TQbW_obJY8OUpJzN-xTuGsgEOviIkauFq5Ky4LgC6YuyukwLVFW1k1SrojP1SA3gpZ3Jr5o9fYx6tMNMH2bGQVsmW7BQsdNI1H3ajroJT6fS_X2',
#     'width': 3968}],
#   'place_id': 'ChIJjcNt0WUtQg0RYzw9sUf0pfM',
#   'plus_code': {'compound_code': 'G9R5+MH Alcobendas',
#    'global_code': '8CGRG9R5+MH'},
#   'rating': 4.6,
#   'reference': 'ChIJjcNt0WUtQg0RYzw9sUf0pfM',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 179},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Av. de Bruselas, 21, 28108 Alcobendas, Madrid, Spain',
#   'geometry': {'location': {'lat': 40.5306254, 'lng': -3.6380058},
#    'viewport': {'northeast': {'lat': 40.53231472989271,
#      'lng': -3.636511370107278},
#     'southwest': {'lat': 40.52961507010727, 'lng': -3.639211029892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'name': 'Miss Sushi Alcobendas',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 367,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117627859932882121174">A Google User</a>'],
#     'photo_reference': 'ATtYBwKLy1c5a403nhU_edrFnpuGYlHrP3Om7YIt3d-qSP6W5S_8e6dPD2DGH30Cytp_0oXL0G-0jsMhc-SuepfCEUoUhq3mcZ3MMNEEFoS0wHjt0nWZXvQfX7Z1y55LQ3zA5GZnKb_acfctBEgKtzuyj9ZxdQfCY27Fy6F4HXvnJMNv2CfO',
#     'width': 550}],
#   'place_id': 'ChIJG0Cz5DItQg0R35e_zKTgMf0',
#   'plus_code': {'compound_code': 'G9J6+7Q Alcobendas',
#    'global_code': '8CGRG9J6+7Q'},
#   'price_level': 2,
#   'rating': 4,
#   'reference': 'ChIJG0Cz5DItQg0R35e_zKTgMf0',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 430},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Calle de la Azalea, 1, 28109 Alcobendas, Madrid, Spain',
#   'geometry': {'location': {'lat': 40.5187224, 'lng': -3.650498099999999},
#    'viewport': {'northeast': {'lat': 40.52006552989272,
#      'lng': -3.649054670107278},
#     'southwest': {'lat': 40.51736587010728, 'lng': -3.651754329892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'name': 'Restaurante Inari Moraleja',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 1333,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117020156032092012917">Restaurante Inari</a>'],
#     'photo_reference': 'ATtYBwJGn77pyWPkV58u4xbA-eWegIqEMq6ukm0P3zwkys6k_RJoH_zW7nLRoyCwq46c4DF8As7VSCBrJulTQgtFj6QAvEPHphfH-AimxndpVN_EuThmsaXMc4rjr4uP7Ym_1takEDFzCzCoo9wPcuTw7hZMyrj-YytIRrok8z5JHdG2Vb1g',
#     'width': 2000}],
#   'place_id': 'ChIJnWQto20sQg0R9fwOEeKi_nI',
#   'plus_code': {'compound_code': 'G89X+FR Alcobendas',
#    'global_code': '8CGRG89X+FR'},
#   'price_level': 2,
#   'rating': 4.4,
#   'reference': 'ChIJnWQto20sQg0R9fwOEeKi_nI',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 452},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Av. Olímpica, 32, 28108 Alcobendas, Madrid, Spain',
#   'geometry': {'location': {'lat': 40.5357017, 'lng': -3.6389148},
#    'viewport': {'northeast': {'lat': 40.53706342989272,
#      'lng': -3.637654270107278},
#     'southwest': {'lat': 40.53436377010728, 'lng': -3.640353929892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'name': 'Go Sushing Alcobendas',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 2848,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112236590328827614239">Go Sushing</a>'],
#     'photo_reference': 'ATtYBwKv__cPoahs3aaluoHT5rJ8ETGAerwucj1J-k9eWVHi2IvpVN0mCID9Ncd9Bpu4VdH8SivR6uyXFm5uOU0UWwr0vXGRO1zvJvvbYsuhcEOqJ2w6eN5RabUpPW0ehfWtw_d-fNvGiX8oib3bkOkJsojJ90mOhaDwx5WXrUdBymCFYMEp',
#     'width': 4288}],
#   'place_id': 'ChIJAc_7tlgsQg0RtXBuw4FQrCc',
#   'plus_code': {'compound_code': 'G9P6+7C Alcobendas',
#    'global_code': '8CGRG9P6+7C'},
#   'price_level': 2,
#   'rating': 4,
#   'reference': 'ChIJAc_7tlgsQg0RtXBuw4FQrCc',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 361},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Calle de Manuel de Falla, 48, 28100 Alcobendas, Madrid, Spain',
#   'geometry': {'location': {'lat': 40.5522148, 'lng': -3.6430362},
#    'viewport': {'northeast': {'lat': 40.55364177989271,
#      'lng': -3.641741670107278},
#     'southwest': {'lat': 40.55094212010727, 'lng': -3.644441329892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'name': 'Moshi Moshi Sushi Bar',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106936062959883178235">Carlos Brito</a>'],
#     'photo_reference': 'ATtYBwLgodQMNT7MDAKyvdpL_CQepStvV8OPdUYiFX14vNaI8FNiYQLDvoSrLM6LtKPy_vxxjKbCvcaeN1LXRZJ0RHSiWV6p_STe_hiO7XIKccPxVPfvK9Z0L4gu1PtAnyQKepT7C4YheA3j5-PRmEX780GeDSnG1o58xy5wqDMnOOX2ygTh',
#     'width': 4032}],
#   'place_id': 'ChIJEVMvoZQsQg0Rk2V_QNxSwQ8',
#   'plus_code': {'compound_code': 'H924+VQ Alcobendas',
#    'global_code': '8CGRH924+VQ'},
#   'price_level': 1,
#   'rating': 4.4,
#   'reference': 'ChIJEVMvoZQsQg0Rk2V_QNxSwQ8',
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 157},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Calle San Juan de Ortega, 24, 28050 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.5049727, 'lng': -3.6753884},
#    'viewport': {'northeast': {'lat': 40.50626617989272,
#      'lng': -3.674165820107279},
#     'southwest': {'lat': 40.50356652010728, 'lng': -3.676865479892723}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'name': 'Restaurante Japones SUSHI COME',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 2448,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108086856223319402475">A Google User</a>'],
#     'photo_reference': 'ATtYBwLhBTIUj17ZO0QSHWC-c03G96JfXss75E-KwTdS8pgS--WzF5bjMSn5i_DqsXk3LJZpcz9tPOPQPEGJDTbtqLvTQwktfz3xTCKK632LxiC8HDF2xYx4sCA8tt9j8gyqRkgruYSk91N-0PX8Ud90zsQeuqCzzWA_sizK2OQRoO3Mh1kP',
#     'width': 3264}],
#   'place_id': 'ChIJcTMdiM4rQg0RAxYDGDhh-GA',
#   'plus_code': {'compound_code': 'G83F+XR Madrid',
#    'global_code': '8CGRG83F+XR'},
#   'price_level': 1,
#   'rating': 4.4,
#   'reference': 'ChIJcTMdiM4rQg0RAxYDGDhh-GA',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 801},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Paseo de Valdelasfuentes, 9, 28100 Alcobendas, Madrid, Spain',
#   'geometry': {'location': {'lat': 40.5511704, 'lng': -3.6539151},
#    'viewport': {'northeast': {'lat': 40.55251832989271,
#      'lng': -3.652518020107278},
#     'southwest': {'lat': 40.54981867010727, 'lng': -3.655217679892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'name': 'panda & sushi alcobendas',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 2880,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112304690415055217927">A Google User</a>'],
#     'photo_reference': 'ATtYBwJdOJIyxWNP2AbH2rR5DTE2-VYVQhMGnxyI-BRyZBCIby52Q3Fs_vbATasK-ZKzkVZz9zKt-afd4Cr79zZfslt7i74u6XO9hHly-T2MxwJb7ag-dlOowAd20ZzP1bnK4VgnOQolXSWxdLaS3zetGrQMO9o64Z3sp-j6U3WpE7Ax4sx-',
#     'width': 2160}],
#   'place_id': 'ChIJE3nyJVItQg0RkJ0CxLEeRFQ',
#   'plus_code': {'compound_code': 'H82W+FC Alcobendas',
#    'global_code': '8CGRH82W+FC'},
#   'rating': 3.9,
#   'reference': 'ChIJE3nyJVItQg0RkJ0CxLEeRFQ',
#   'types': ['restaurant',
#    'meal_takeaway',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'user_ratings_total': 74},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Urb. La Moraleja, Calle de la Estafeta, 2, 28109 Alcobendas, Madrid, Spain',
#   'geometry': {'location': {'lat': 40.5145944, 'lng': -3.6528861},
#    'viewport': {'northeast': {'lat': 40.51576727989271,
#      'lng': -3.651302770107278},
#     'southwest': {'lat': 40.51306762010727, 'lng': -3.654002429892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'name': '99 Sushi Bar',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 709,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102664686777975500489">99 Sushi Bar Moraleja</a>'],
#     'photo_reference': 'ATtYBwKkde44ZR79KTHH2rTF67MikeVncsnbUqv8Sk4DLj_ZTorGwJHRX-rCtsiMqOktLC_APmKevp5eW6IPHS7sSnAfRrzezjAj6Fw7AnXBUzffWdo2BYPczzlYroG0VAdY5OJrVzrT4l5tSiR8PJh3wBroW0rilblpd4sjoSnEnBC1kZnT',
#     'width': 962}],
#   'place_id': 'ChIJL7K1aA0sQg0RcIgHDPDHczA',
#   'plus_code': {'compound_code': 'G87W+RR Alcobendas',
#    'global_code': '8CGRG87W+RR'},
#   'price_level': 4,
#   'rating': 4.5,
#   'reference': 'ChIJL7K1aA0sQg0RcIgHDPDHczA',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 313},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Av. de Europa, 13-15, 28108 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.5190236, 'lng': -3.655711},
#    'viewport': {'northeast': {'lat': 40.52009897989273,
#      'lng': -3.654390670107277},
#     'southwest': {'lat': 40.51739932010728, 'lng': -3.657090329892721}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'name': 'Elim',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 2976,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113022750128247924570">箭矢阮</a>'],
#     'photo_reference': 'ATtYBwIA9DZdduQmH-HM7S6ll8lHuFhkvzMqOnkJBDSeP_UfneUdrlG_vXBFCuN2SQ3-GxfG-nzrjakKvKkGKY__7GZQyd9au7IMlQJT0zjtXaW39brfyEjpkfVeXtUeX-BWcxILaKuptSLgUaCdBV35ig69A_upuu2PA5XLxX3CNEfuGFA1',
#     'width': 3968}],
#   'place_id': 'ChIJsfQvpHMsQg0RwoXD3yhTjEE',
#   'plus_code': {'compound_code': 'G89V+JP Madrid',
#    'global_code': '8CGRG89V+JP'},
#   'rating': 3.9,
#   'reference': 'ChIJsfQvpHMsQg0RwoXD3yhTjEE',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 277},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Av. de la Industria, 9, 28108 Alcobendas, Madrid, Spain',
#   'geometry': {'location': {'lat': 40.5346164, 'lng': -3.645651099999999},
#    'viewport': {'northeast': {'lat': 40.53612972989271,
#      'lng': -3.644350770107277},
#     'southwest': {'lat': 40.53343007010726, 'lng': -3.647050429892721}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'name': 'Sushi Maker',
#   'place_id': 'ChIJ29ZipWEsQg0Rv7WVBSstS7E',
#   'plus_code': {'compound_code': 'G9M3+RP Alcobendas',
#    'global_code': '8CGRG9M3+RP'},
#   'rating': 0,
#   'reference': 'ChIJ29ZipWEsQg0Rv7WVBSstS7E',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 0},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Calle Cardenal Tavera, 2, 28050 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4951208, 'lng': -3.6592479},
#    'viewport': {'northeast': {'lat': 40.49637562989272,
#      'lng': -3.658005120107279},
#     'southwest': {'lat': 40.49367597010727, 'lng': -3.660704779892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'name': 'Hamachi Sushi. Cocina Japon',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 2736,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109164498891471768837">A Google User</a>'],
#     'photo_reference': 'ATtYBwIinN0Fygu3I3ANG29RCEQ6PJJj0RBJxRm9Wxxj1HJ1TNrT2thya1FJ4rKRONXoLiu1msxk2RGtl1iGDa4K_ZXH2kWn6WE80I-T2McQcbfv-HYwhQoGx_ZGOKePGhONDNn1D5pKugc4-vW3_ycr_7z804slBfxFaz7-YDGunFZ5KIw-',
#     'width': 3648}],
#   'place_id': 'ChIJV12h0wEvQg0RENkSNEyVwZg',
#   'plus_code': {'compound_code': 'F8WR+28 Madrid',
#    'global_code': '8CGRF8WR+28'},
#   'rating': 4.6,
#   'reference': 'ChIJV12h0wEvQg0RENkSNEyVwZg',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 342},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Av de Somosierra, 20, 28703 San Sebastián de los Reyes, Madrid, Spain',
#   'geometry': {'location': {'lat': 40.55450099999999, 'lng': -3.6157672},
#    'viewport': {'northeast': {'lat': 40.55579657989272,
#      'lng': -3.614473220107278},
#     'southwest': {'lat': 40.55309692010727, 'lng': -3.617172879892721}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'name': 'Hak',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 1200,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106671187785827268826">Maria Fernanda Perez</a>'],
#     'photo_reference': 'ATtYBwIUPBC0XNbXQR-m8pfJxkFNoYdDW-ElGblXWnhShtTXx-rZNLhDDBBjZkkR0rMm0GRZnKAI8ifJAmd9PbMnKMDkwn__5Nl-9FIFCTqroKsywWRoattKAvp5SK-0FGABofncST45EEq-JTga_uulKKfa_7ANGppOEIsWrk52l3oo6_M4',
#     'width': 1600}],
#   'place_id': 'ChIJZxcTORktQg0RIRS_dfBLTHg',
#   'plus_code': {'compound_code': 'H93M+RM San Sebastián de los Reyes',
#    'global_code': '8CGRH93M+RM'},
#   'price_level': 1,
#   'rating': 4.1,
#   'reference': 'ChIJZxcTORktQg0RIRS_dfBLTHg',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 356},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Glorieta Monte del Gozo, 3, 28050 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.5100611, 'lng': -3.6672476},
#    'viewport': {'northeast': {'lat': 40.51165867989273,
#      'lng': -3.665992370107279},
#     'southwest': {'lat': 40.50895902010728, 'lng': -3.668692029892723}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'name': 'Kyoka Las Tablas',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 1920,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110608366495437006289">A Google User</a>'],
#     'photo_reference': 'ATtYBwJ9gdMPBBXYPIuwQcnAn4Ty4lR7r_cskotdsbyapEhRfdOriTLhbtUlu-N8Y8O2pcQlj5ONkDcU_XzWq-ag6OwT_qnEg0a5qccvWUY-xjPCKsreNMBpqi68Imdj5XS2DSviWLbwzQtLjS8VS-0nVxPOx9_am2BczKvMSgzIkgTfjiXG',
#     'width': 1080}],
#   'place_id': 'ChIJt-t2N6ErQg0R_lUZNIWsq9Y',
#   'plus_code': {'compound_code': 'G86M+24 Madrid',
#    'global_code': '8CGRG86M+24'},
#   'price_level': 2,
#   'rating': 4.2,
#   'reference': 'ChIJt-t2N6ErQg0R_lUZNIWsq9Y',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 941},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Avda. MONTECARMELO, 28049 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.5055237, 'lng': -3.698956},
#    'viewport': {'northeast': {'lat': 40.50684807989272,
#      'lng': -3.697650920107279},
#     'southwest': {'lat': 40.50414842010728, 'lng': -3.700350579892723}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'name': 'Taiko Sushi Bar',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 568,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103183758730307141310">Taiko Sushi Bar -Restaurante Japonés</a>'],
#     'photo_reference': 'ATtYBwIkAPI6AnF6_NK9BfA6f180Tml3tj9wUb0Nx694FuCCjkOjyruw_Yk80_mgIwjuriEgauDiJeO4NBFJHnIbGh6BUFSkRG54Aqrg34Ck2_1FcYTPzMVa6TNiI1ch0CW5plkyRo5ANPG_qaeqKAPuMDh7qXnNfIuTH-X9IcM2yVyvsEYp',
#     'width': 1009}],
#   'place_id': 'ChIJtbzf980rQg0Rmgz1zSiIUhw',
#   'plus_code': {'compound_code': 'G842+6C Madrid',
#    'global_code': '8CGRG842+6C'},
#   'price_level': 2,
#   'rating': 4.3,
#   'reference': 'ChIJtbzf980rQg0Rmgz1zSiIUhw',
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 439},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Av. de Bruselas, 21, Local 23B, 28108 Alcobendas, Madrid, Spain',
#   'geometry': {'location': {'lat': 40.530241, 'lng': -3.6386274},
#    'viewport': {'northeast': {'lat': 40.53163872989272,
#      'lng': -3.637258370107278},
#     'southwest': {'lat': 40.52893907010728, 'lng': -3.639958029892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'name': 'UDON',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 1363,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108348388410833109439">UDON Diversia</a>'],
#     'photo_reference': 'ATtYBwKLKDENDXX-Tfzs1ZylXQKc5HroNZiRmwwZNq_IuRk-WHScXQflAIePV1RB8z8ICtq-QmEYhJwFMJ_3uSqQLod-ovLb_599ZKTgF8MGFSlHuZoOiUXujo7ru3avWe_V-CS-Z9A3Fa_8aIVALzgz2CH980u875ZF7Me9p-CvxiFwKyyY',
#     'width': 2048}],
#   'place_id': 'ChIJXUA5SVwsQg0RBec0DgcH_U8',
#   'plus_code': {'compound_code': 'G9J6+3G Alcobendas',
#    'global_code': '8CGRG9J6+3G'},
#   'price_level': 2,
#   'rating': 3.8,
#   'reference': 'ChIJXUA5SVwsQg0RBec0DgcH_U8',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 317},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Av. del Monasterio de El Escorial, 26, 28049 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.50428350000001, 'lng': -3.706197},
#    'viewport': {'northeast': {'lat': 40.50571582989271,
#      'lng': -3.704839920107278},
#     'southwest': {'lat': 40.50301617010727, 'lng': -3.707539579892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'name': 'Hinoiri Restaurante Japonés en Montecarmelo',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 810,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116461458929886403193">A Google User</a>'],
#     'photo_reference': 'ATtYBwIXPtKXt1eyc6m74zuLeOxWuM4xr84yM-Knf3BHJpJdqxhFO2kLjIlOuN9Rieks8jcUWQoZk2VNVOuYYwfHU1lDoUqVF6VhmTXoW7OSxAV_cWJKqVNos6JGWPACX7TrNAi7lwIlqpI_hwbi0kWW-DKzwuV-zXrc5Ek0mIfiJR-AtGZn',
#     'width': 1440}],
#   'place_id': 'ChIJpUMYcJUrQg0R2UMY55SIBhM',
#   'plus_code': {'compound_code': 'G73V+PG Madrid',
#    'global_code': '8CGRG73V+PG'},
#   'rating': 4.2,
#   'reference': 'ChIJpUMYcJUrQg0R2UMY55SIBhM',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 126},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'C. de Frómista, 5, 28050 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.5092116, 'lng': -3.6773928},
#    'viewport': {'northeast': {'lat': 40.51043367989272,
#      'lng': -3.676264470107278},
#     'southwest': {'lat': 40.50773402010728, 'lng': -3.678964129892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'name': 'Maki',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 1365,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109006590579754300452">MAKI Las Tablas</a>'],
#     'photo_reference': 'ATtYBwJmCj7b08AmB0e9udUtsJWy8h4aMbejGN_9iaYLWVTlTgKE0tKRD_74B_1rkhqIysmVupkD38ctOcTDAYYjkvaB_r4FuOpriGmPD7wlQZx2GOLn0DgOz4oBVBX0_iznNNSbGmJ9KNLGLK2cTudONCoG34AWOzkTMzR_M6EZKhV9Lj8',
#     'width': 2048}],
#   'place_id': 'ChIJe8y4CKAuQg0RrjMzSlCQeDw',
#   'plus_code': {'compound_code': 'G85F+M2 Madrid',
#    'global_code': '8CGRG85F+M2'},
#   'price_level': 1,
#   'rating': 4,
#   'reference': 'ChIJe8y4CKAuQg0RrjMzSlCQeDw',
#   'types': ['meal_delivery',
#    'meal_takeaway',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'user_ratings_total': 315}]

# %%
for place in lista:
    query = place + " in madrid"
    name_1 = gp.gp_call(query)
    time.sleep(2)
    try: 
        name_2 = gp.next_page(name_1["next_page_token"])
        time.sleep(2)
        name_3 = gp.next_page(name_2["next_page_token"])
        time.sleep(2)
        df_name_1 = gp.request_to_df(name_1)
        df_name_2 = gp.request_to_df(name_2)
        df_name_3 = gp.request_to_df(name_3)
        df_name_1["place"] = place
        df_name_2["place"] = place
        df_name_3["place"] = place
        df = pd.concat([df_name_1,df_name_2, df_name_3])
        save = "data/" + place + ".csv"
        df = df.reset_index()
        df = df.drop(["index"],axis=1)
        df.to_csv(save)
    except: 
        df = gp.request_to_df(name_1)
        df["place"] = place
        save = "data/" + place + ".csv"
        df = df.reset_index()
        df = df.drop(["index"],axis=1)
        df.to_csv(save)

# %%
import numpy as np
np.nan
# Out:
# nan
