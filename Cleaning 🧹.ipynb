# %%
import pandas as pd

# %%
lista = ["cinema", "museum", "park", "zoo", "japanese",
         "burger", "vietnamese", "tapas", "korean", "brewery",
         "club", "pub", "bowling", "greek", "juices", "vegan",
         "french", "mexican", "asian", "rooftop", "cocktail", 
         "nightlife", "ramen", "argentino", "grill", "italian",
         "thai", "cake", "cupcakes", "coffee", "mid eastern",
         "indian", "pizza", "sweets", "theater", "spa", "ice cream",
         "sports bar", "healthy", "vegetarian", "drinks",
         "jazz", "wine", "karaoke", "dancing", "seafood", "discoteca", "escape room",
         "centro comercial", "pista padel", "pista tenis", "campo de futbol", 
         "paintball", "multiaventura", "cancha baloncesto", "gluten free", 
         "autocine", "cata de vino", "pista de hielo", "senderismo"
         ]

# %%
for place in lista:
    name = "data/" + place + ".csv"
    locals()[place] = pd.read_csv(name, index_col=0)

# %%
df_names = []
for place in lista:
    df_names.append(locals()[place])

# %%
df = pd.concat(df_names, ignore_index=True)

# %%
df.shape
# Out:
# (3079, 6)

# %%
df.sample(15)
# Out:
#                                               name  rating  \
# 2221                        Karaoke Singer´s House     3.6
# 1184                      Grazie Mille Kitchen bar     4.1
# 1305                        Fika Patisserie Madrid     5.0
# 2674                               Club Mirasierra     4.3
# 659                           Chicken Of the Woods     4.9
# 2884           Canchas de baloncesto Arroyopozuelo     0.0
# 1697              Flamenco Essential Flamenco Show     4.7
# 2442                                        El Sol     4.3
# 417                           Viuda de Cortés S.L.     0.0
# 1009                                      The Dash     4.4
# 211                                          Naomi     4.6
# 1101                              Empanadas Malvón     4.6
# 2268  Flow escuela de baile y pole dance EN MADRID     4.6
# 2070                   Cometapas - Tapas en Madrid     4.0
# 810                                  El Chaparrito     4.3
#
#                                                location  \
# 2221  {'type': 'Point', 'coordinates': [-3.657579, 4...
# 1184  {'type': 'Point', 'coordinates': [-3.707516, 4...
# 1305  {'type': 'Point', 'coordinates': [-3.672964099...
# 2674  {'type': 'Point', 'coordinates': [-3.704151, 4...
# 659   {'type': 'Point', 'coordinates': [-3.7078083, ...
# 2884  {'type': 'Point', 'coordinates': [-3.7733528, ...
# 1697  {'type': 'Point', 'coordinates': [-3.7027271, ...
# 2442  {'type': 'Point', 'coordinates': [-3.7016321, ...
# 417   {'type': 'Point', 'coordinates': [-3.7245116, ...
# 1009  {'type': 'Point', 'coordinates': [-3.7006417, ...
# 211   {'type': 'Point', 'coordinates': [-3.7006115, ...
# 1101  {'type': 'Point', 'coordinates': [-3.6824001, ...
# 2268  {'type': 'Point', 'coordinates': [-3.6998981, ...
# 2070  {'type': 'Point', 'coordinates': [-3.72473, 40...
# 810   {'type': 'Point', 'coordinates': [-3.698896599...
#
#                                                 address  price_level  \
# 2221          Av. de Moratalaz, 45, 28030 Madrid, Spain          2.0
# 1184               Calle Mayor, 31, 28013 Madrid, Spain          2.0
# 1305       Calle de Costa Rica, 26, 28016 Madrid, Spain          NaN
# 2674    Calle de la Costa Brava, 8, 28034 Madrid, Spain          NaN
# 659          Calle de la Palma, 63, 28015 Madrid, Spain          NaN
# 2884                                28023 Madrid, Spain          NaN
# 1697          Calle de la Cruz, 26, 28012 Madrid, Spain          NaN
# 2442      Calle de los Jardines, 3, 28013 Madrid, Spain          NaN
# 417        Paseo de la Florida, 51, 28008 Madrid, Spain          NaN
# 1009              C/ de Murillo, 5, 28010 Madrid, Spain          2.0
# 211             Calle de Ávila, 14, 28020 Madrid, Spain          2.0
# 1101          Calle de Alcalá, 109, 28009 Madrid, Spain          NaN
# 2268       Calle de San Germán, 56, 28020 Madrid, Spain          NaN
# 2070           Plaza de Coímbra, 4, 28025 Madrid, Spain          1.0
# 810   Calle de Ventura de la Vega, 11, 28014 Madrid,...          1.0
#
#                   place
# 2221            karaoke
# 1184            italian
# 1305               cake
# 2674        pista tenis
# 659               vegan
# 2884  cancha baloncesto
# 1697            theater
# 2442          discoteca
# 417             brewery
# 1009          nightlife
# 211            japanese
# 1101          argentino
# 2268            dancing
# 2070             drinks
# 810             mexican

# %% [markdown]
# **Price Level**
# 0 — Free
# 1 — Inexpensive
# 2 — Moderate
# 3 — Expensive
# 4 — Very Expensive
