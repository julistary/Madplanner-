# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = "https://www.cinesa.es/peliculas/cartelera"
html = requests.get(url)
soup = BeautifulSoup(html.content, "html.parser")

# %%
films = soup.find_all("a", {"class": "vf"})

# %%
list_of_films = [a.getText().strip() for a in films]
list_of_films_cleaned = []
for index,f in enumerate(list_of_films):
    if index%2 == 0:
        list_of_films_cleaned.append(f)
list_of_films_cleaned
# Out:
# ['¡Upsss! 2 ¿Y ahora dónde está Noé?',
#  '4 días',
#  'Amanece en Calcuta',
#  'Aquellos que desean mi muerte',
#  'Barbie y Chelsea, el cumpleaños perdido',
#  'Boda sin fin',
#  'Borrar el historial',
#  'Chaos Walking',
#  'Crónica de una tormenta',
#  'Cuñados',
#  'Detective Conan: La bala escarlata',
#  'Earwig y la bruja',
#  'El fotógrafo de Minamata',
#  'El olvido que seremos',
#  'El Padre',
#  'El señor de los anillos: el retorno del rey',
#  'El señor de los anillos: la comunidad del anillo',
#  'El señor de los anillos: las dos torres',
#  'Este cuerpo me sienta de muerte',
#  'Godzilla vs. Kong',
#  'Guardianes de la Noche: Tren infinito',
#  'Inmune',
#  'Los Croods: Una Nueva Era',
#  'Mamá María',
#  'Maratón El señor de los anillos',
#  'Monster Hunter',
#  'Mortal Kombat',
#  'Nadie',
#  'Otra ronda',
#  'Quo vadis, Aida?',
#  'Ruega por nosotros',
#  'Saw VIII',
#  'Spiral: Saw',
#  'Tiburón blanco',
#  'Todas las lunas',
#  'Tom y Jerry',
#  'Una joven prometedora',
#  'Una veterinaria en la Borgoña',
#  'Wonder Woman 1984',
#  'Yalda, la noche del perdón']

# %%
dict_films = {"film" : list_of_films_cleaned}

# %%
pd.DataFrame.from_dict(dict_films, orient = "columns")
# Out:
#                                                 film
# 0                 ¡Upsss! 2 ¿Y ahora dónde está Noé?
# 1                                             4 días
# 2                                 Amanece en Calcuta
# 3                      Aquellos que desean mi muerte
# 4            Barbie y Chelsea, el cumpleaños perdido
# 5                                       Boda sin fin
# 6                                Borrar el historial
# 7                                      Chaos Walking
# 8                            Crónica de una tormenta
# 9                                            Cuñados
# 10                Detective Conan: La bala escarlata
# 11                                 Earwig y la bruja
# 12                          El fotógrafo de Minamata
# 13                             El olvido que seremos
# 14                                          El Padre
# 15       El señor de los anillos: el retorno del rey
# 16  El señor de los anillos: la comunidad del anillo
# 17           El señor de los anillos: las dos torres
# 18                   Este cuerpo me sienta de muerte
# 19                                 Godzilla vs. Kong
# 20             Guardianes de la Noche: Tren infinito
# 21                                            Inmune
# 22                         Los Croods: Una Nueva Era
# 23                                        Mamá María
# 24                   Maratón El señor de los anillos
# 25                                    Monster Hunter
# 26                                     Mortal Kombat
# 27                                             Nadie
# 28                                        Otra ronda
# 29                                  Quo vadis, Aida?
# 30                                Ruega por nosotros
# 31                                          Saw VIII
# 32                                       Spiral: Saw
# 33                                    Tiburón blanco
# 34                                   Todas las lunas
# 35                                       Tom y Jerry
# 36                             Una joven prometedora
# 37                     Una veterinaria en la Borgoña
# 38                                 Wonder Woman 1984
# 39                        Yalda, la noche del perdón
