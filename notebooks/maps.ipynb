# %%
import pandas as pd
import geopandas
from folium import Circle, Marker, Icon, Map
from pymongo import MongoClient, GEOSPHERE
conn = MongoClient("localhost:27017")
db = conn.get_database("madrid")
import requests
import unicodedata 
import json
#from dotenv import load_dotenv
#import os

# %%
df_m = pd.read_csv("data/df_districts_2.csv",index_col=0)

# %%
df_m
# Out:
#                Distrito   latitude  longitude
# 0             HORTALEZA  40.469596  -3.643167
# 1   FUENCARRAL-EL PARDO  40.533515  -3.783734
# 2         CIUDAD LINEAL  40.445464  -3.657771
# 3   SAN BLAS-CANILLEJAS  40.432949  -3.615435
# 4               BARAJAS  40.465524  -3.592670
# 5             MORATALAZ  40.407016  -3.654802
# 6    PUENTE DE VALLECAS  40.386757  -3.668604
# 7             VICALVARO  40.393974  -3.598987
# 8     VILLA DE VALLECAS  40.367776  -3.607974
# 9            VILLAVERDE  40.347168  -3.710154
# 10                USERA  40.382845  -3.710909
# 11          CARABANCHEL  40.379049  -3.744533
# 12               LATINA  40.402683  -3.748553
# 13      MONCLOA-ARAVACA  40.444091  -3.748666
# 14               CENTRO  40.411815  -3.707871
# 15               TETUAN  40.458787  -3.697805
# 16            CHAMARTIN  40.462163  -3.680515
# 17             CHAMBERI  40.434696  -3.713535
# 18               RETIRO  40.410908  -3.673866
# 19           ARGANZUELA  40.398548  -3.706817
# 20            SALAMANCA  40.428173  -3.684678

# %%
def barrio_a_coordenadas(df_madrid,df_m, district):
    coordinates = {}
    district = unicodedata.normalize('NFD', district)\
    .encode('ascii', 'ignore')\
    .decode("utf-8")
    lista_distritos = ['fuencarral-el pardo', 'hortaleza', 'ciudad lineal', 'san blas-canillejas',
                       'barajas', 'moratalaz', 'puente de vallecas', 'vicalvaro',
                       'villa de vallecas', 'villaverde', 'usera', 'carabanchel', 'latina', 
                       'moncloa-aravaca', 'centro', 'tetuan', 'chamartin', 'chamberi', 'retiro',
                       'arganzuela', 'salamanca']
    if district.lower() in lista_distritos:
        district = district.upper()
        print(district)
        for index, row in df_m.iterrows():
            if district.upper() in row.Distrito.upper():
                coordinates["latt"] = row["latitude"]
                coordinates["long"] = row["longitude"]           
                break
        
    else:
        for index, row in df_madrid.iterrows():
            if district.upper() in row.poblacion.upper():
                coordinates["latt"] = row["lon"][:6]
                coordinates["long"] = row["lat"][:6]            
                break
    return coordinates

# %%
barrio_a_coordenadas(df_madrid,df_m, "tetuan")
# Out:
# TETUAN
# {'latt': 40.45878707931132, 'long': -3.697804567301735}

# %% [markdown]
# ## Distrito -> coordenadas

# %% [markdown]
# ### Pueblo

# %%
df_madrid = pd.read_csv("data/df_madrid.csv",index_col=0)

# %%
df_madrid.head()
# Out:
#   provincia          poblacion     CP             lat             lon
# 0    Madrid            Ajalvir  28864  -3.480.710.160  40.535.068.130
# 1    Madrid  Alameda del Valle  28742  -3.843.661.950  40.916.583.150
# 2    Madrid           El Alamo  28607  -3.990.797.560  40.228.256.070
# 3    Madrid           El Alamo  28807  -3.990.797.560  40.228.256.070
# 4    Madrid  Alcala de Henares  28801  -3.369.251.020  40.480.332.320

# %%
municipios = ['Móstoles', 'Alcalá de Henares','Fuenlabrada',
'Leganés','Getafe','Alcorcón','Torrejón de Ardoz',
'Parla','Alcobendas', 'Las Rozas de Madrid', 'San Sebastián de los Reyes',
'Rivas-Vaciamadrid','Pozuelo de Alarcón', 'Coslada', 'Valdemoro',
'Majadahonda' , 'Collado Villalba', 'Aranjuez', 'Arganda del Rey',
'Boadilla del Monte', 'Pinto','Colmenar Viejo','Tres Cantos',
'San Fernando de Henares','Galapagar','Arroyomolinos','Navalcarnero',
'Villaviciosa de Odón','Paracuellos de Jarama','Ciempozuelos','Torrelodones',
'Mejorada del Campo','Villanueva de la Cañada','Algete','Humanes de Madrid',
'San Martín de la Vega','San Lorenzo de El Escorial','Villanueva del Pardillo', 'El Escorial']

# %% [markdown]
# ### Distritos

# %%
df_distritos = pd.read_csv("data/df_districts.csv",index_col=0)

# %%
list(df_distritos.Distrito.unique())
# Out:
# ['FUENCARRAL-EL PARDO ',
#  'HORTALEZA           ',
#  'CIUDAD LINEAL       ',
#  'SAN BLAS-CANILLEJAS ',
#  'BARAJAS             ',
#  'MORATALAZ           ',
#  'PUENTE DE VALLECAS  ',
#  'VICALVARO           ',
#  'VILLA DE VALLECAS   ',
#  'VILLAVERDE          ',
#  'USERA               ',
#  'CARABANCHEL         ',
#  'LATINA              ',
#  'MONCLOA-ARAVACA     ',
#  'CENTRO              ',
#  'TETUAN              ',
#  'CHAMARTIN           ',
#  'CHAMBERI            ',
#  'RETIRO              ',
#  'ARGANZUELA          ',
#  'SALAMANCA           ']

# %%
df_distritos[df_distritos["Distrito"]=='FUENCARRAL-EL PARDO ']
# Out:
#                Distrito     CP
# 0  FUENCARRAL-EL PARDO   28034

# %%
lista_distritos = ['fuencarral','el pardo', 'hortaleza', 'ciudad lineal', 'san blas','canillejas', 'barajas', 'moratalaz', 'puente de vallecas', 'vicalvaro', 'villa de vallecas', 'villaverde', 'usera', 'carabanchel', 'latina', 'moncloa','aravaca', 'centro', 'tetuan', 'chamartin', 'chamberi', 'retiro', 'arganzuela', 'salamanca']

# %% [markdown]
# ### Distrito -> coordenadas

# %%
district = input("Selecciona un barrio/municipio de Madrid: ")
# Out:
# Selecciona un barrio/municipio de Madrid: fuencarral

# %%
def barrio_a_coordenadas(df_madrid,df_distritos, district):
    coordinates = {}
    district = unicodedata.normalize('NFD', district)\
    .encode('ascii', 'ignore')\
    .decode("utf-8")
    print(district)
    lista_distritos = ['fuencarral','el pardo', 'hortaleza', 'ciudad lineal', 'san blas',
                       'canillejas', 'barajas', 'moratalaz', 'puente de vallecas', 'vicalvaro',
                       'villa de vallecas', 'villaverde', 'usera', 'carabanchel', 'latina', 
                       'moncloa','aravaca', 'centro', 'tetuan', 'chamartin', 'chamberi', 'retiro',
                       'arganzuela', 'salamanca']
    if district.lower() in lista_distritos:
        district = district.upper()
        cp = 28037
        for index, row in df_distritos.iterrows():
            if district in row.Distrito:
                cp = row.CP
        datos = requests.get(f"https://geocode.xyz/{cp}?json=1").json()
        datos = datos["alt"]["loc"]
        for country in datos:
            if country['countryname'] == "Spain":
                coordinates["latt"] = country["latt"]
                coordinates["long"] = country["longt"]
    else:
        for index, row in df_madrid.iterrows():
            if district.upper() in row.poblacion.upper():
                coordinates["latt"] = row["lon"][:6]
                coordinates["long"] = row["lat"][:6]            
                break
    return coordinates

# %%
coordinates = barrio_a_coordenadas(df_madrid,df_distritos,"fuencarral")
# Out:
# fuencarral

# %%
coordinates
# Out:
# {'latt': '40.49341', 'long': '-3.69538'}

# %% [markdown]
# ## Geoquery

# %%
def geoquery(coordinates):
    collection = db.get_collection("todo")
    coord_point = {"type":"Point", "coordinates": [float(coordinates['latt']), float(coordinates['long'])]}
    query = {"geometry": {"$near": {"$geometry": coord_point,"$minDistance": 0, "$maxDistance": 1500}}}
    query_final = collection.find(query)
    df = pd.DataFrame((query_final))
    return df

# %%
df = geoquery(barrio_a_coordenadas(df_madrid,df_distritos,"fuencarral"))
# Out:
# fuencarral

# %%
df.head()
# Out:
#                         _id                                           name  \
# 0  60a24ec13bf0b671a9dbcf80  Instalación Deportiva Básica Andrés Navarrete
# 1  60a24ec13bf0b671a9dbcf6e                 Alquiler campo futbol 7 Madrid
# 2  60a24ec266f0012f7160994a                      Braille-Caldas de Estrach
# 3  60a24ec266f0012f71609db8                           Herrera Oria-Sicilia
# 4  60a24ec126f6881d42044544                                Barrio Sta. Ana
#
#    rating                                            address  price_level  \
# 0     3.9  Calle Hospitalet de Llobregat, 11, 28034 Madri...          1.0
# 1     5.0  Calle Hospitalet de Llobregat, 13, 28034 Madri...          1.0
# 2     NaN                                                NaN          NaN
# 3     NaN                                                NaN          NaN
# 4     NaN                                                NaN          NaN
#
#              place       type   subtype     CP   latitude  longitude  \
# 0  campo de futbol       plan  outdoors  28034  40.494557  -3.694783
# 1  campo de futbol       plan  outdoors  28034  40.494890  -3.695282
# 2              bus  transport       NaN    NaN  40.495842  -3.696119
# 3              bus  transport       NaN    NaN  40.490778  -3.694820
# 4            metro  transport       NaN    NaN  40.495090  -3.693260
#
#                                             geometry  price
# 0  {'type': 'Point', 'coordinates': [40.4945566, ...  1-15€
# 1  {'type': 'Point', 'coordinates': [40.49489, -3...  1-15€
# 2  {'type': 'Point', 'coordinates': [40.495841799...    NaN
# 3  {'type': 'Point', 'coordinates': [40.490777577...    NaN
# 4  {'type': 'Point', 'coordinates': [40.49509, -3...    NaN

# %% [markdown]
# ## DF

# %%
def df_planes_bonito(df):
    df_plan = df[df["type"]=="plan"]
    df_plan = df_plan.set_index("name")
    try:
        df_plan = df_plan.drop(["_id","CP","price_level", "type","subtype", "latitude", "longitude", "geometry"],axis=1)
        df_plan = df_plan.drop_duplicates()
        return df_plan
    except: 
        pass

# %%
df_plan = df_planes_bonito(geoquery(barrio_a_coordenadas(df_madrid,df_distritos,"fuencarral")))
# Out:
# fuencarral

# %%
df_plan
# Out:
#                                                rating  \
# name
# Instalación Deportiva Básica Andrés Navarrete     3.9
# Alquiler campo futbol 7 Madrid                    5.0
# Tartas con Estilo                                 5.0
# Federación de Tenis de Madrid - Fuencarral        4.3
# www.paintballexcape.com                           0.0
# Pádel Tres Olivos                                 3.9
# Bar Terraza Motown                                4.3
# Cake Dream                                        5.0
# Campo de futbol 7. Istalacion deportiva           4.5
# Queen Burger Gourmet                              4.4
# Escalada pared regletas                           0.0
# Club Mirasierra                                   4.3
# ABSARA SPA WELLNESS                               3.7
# Caroli Health Club                                4.2
# Dance Studio Montecarmelo                         4.7
# MacLaren's Irish & Sports Bar - Vaguada           4.3
# MacLaren's Irish & Sports Bar - Vaguada           4.3
#
#                                                                                          address  \
# name
# Instalación Deportiva Básica Andrés Navarrete  Calle Hospitalet de Llobregat, 11, 28034 Madri...
# Alquiler campo futbol 7 Madrid                 Calle Hospitalet de Llobregat, 13, 28034 Madri...
# Tartas con Estilo                              Barrio de Fuencarral No tenemos tienda física,...
# Federación de Tenis de Madrid - Fuencarral     Calle de San Cugat del Vallés, s/n, 28034 Madr...
# www.paintballexcape.com                         C. de Alfredo Marqueríe, 11, 28034 Madrid, Spain
# Pádel Tres Olivos                              Calle Cueva De Montesinos, 0 S N Urbanización ...
# Bar Terraza Motown                             Calle de Fermín Caballero, 7, posterior, 28034...
# Cake Dream                                     Calle de Fermín Caballero, 7, 28034 Madrid, Spain
# Campo de futbol 7. Istalacion deportiva                                      28034 Madrid, Spain
# Queen Burger Gourmet                               Calle de San Modesto, 34, 28034 Madrid, Spain
# Escalada pared regletas                        Calle de Santiago de Compostela, 28034 Madrid,...
# Club Mirasierra                                  Calle de la Costa Brava, 8, 28034 Madrid, Spain
# ABSARA SPA WELLNESS                            Calle de Alfredo Marquerie, 43, 28034 Madrid, ...
# Caroli Health Club                             Hotel Eurostars Suites Mirasierra, C. de Alfre...
# Dance Studio Montecarmelo                      Av. del Monasterio de El Escorial, 40D, 28049 ...
# MacLaren's Irish & Sports Bar - Vaguada        Calle de Santiago de Compostela, 40, 28034 Mad...
# MacLaren's Irish & Sports Bar - Vaguada        Calle de Santiago de Compostela, 40, 28034 Mad...
#
#                                                          place          price
# name
# Instalación Deportiva Básica Andrés Navarrete  campo de futbol          1-15€
# Alquiler campo futbol 7 Madrid                 campo de futbol          1-15€
# Tartas con Estilo                                         cake         15-25€
# Federación de Tenis de Madrid - Fuencarral         pista tenis          1-15€
# www.paintballexcape.com                              paintball         15-25€
# Pádel Tres Olivos                                  pista padel          1-15€
# Bar Terraza Motown                                   piano bar          1-15€
# Cake Dream                                                cake         15-25€
# Campo de futbol 7. Istalacion deportiva        campo de futbol          1-15€
# Queen Burger Gourmet                                    burger         15-25€
# Escalada pared regletas                               climbing  More than 50€
# Club Mirasierra                                    pista tenis          1-15€
# ABSARA SPA WELLNESS                                        spa         25-50€
# Caroli Health Club                                         spa         25-50€
# Dance Studio Montecarmelo                              dancing         15-25€
# MacLaren's Irish & Sports Bar - Vaguada                    pub          1-15€
# MacLaren's Irish & Sports Bar - Vaguada             sports bar          1-15€

# %%
df.columns
# Out:
# Index(['_id', 'name', 'rating', 'address', 'price_level', 'place', 'type',
#        'subtype', 'CP', 'latitude', 'longitude', 'geometry', 'price'],
#       dtype='object')

# %%
def df_tpte_bonito(df):
    df_tpte = df[df["type"]=="transport"]
    df_tpte = df_tpte.set_index("name")
    try:
        df_tpte = df_tpte.drop(["subtype","rating","_id","CP","price_level","address", "type", "latitude", "longitude", "geometry","price"],axis=1)
        df_tpte = df_tpte.drop_duplicates()
        df_tpte = df_tpte.rename(columns={"place":"mean of transport near"})
        df_tpte = df_tpte.set_index("mean of transport near")
        return df_tpte
    except:
        df_tpte = df_tpte.drop(['_id', 'latitude', 'longitude', 'geometry', 'type'],axis=1)
        df_tpte = df_tpte.drop_duplicates()
        df_tpte = df_tpte.rename(columns={"place":"mean of transport near"})
        df_tpte = df_tpte.set_index("mean of transport near")
        return df_tpte

# %%
df_tpte = df_tpte_bonito(df)

# %%
df_tpte
# Out:
# Empty DataFrame
# Columns: []
# Index: [bus, metro, train, parking]

# %% [markdown]
# ## MAP

# %%
def mapita(df,coordinates):
    map_1 = Map(location=[float(coordinates['latt']), float(coordinates['long'])],zoom_start=15)

    for i, row in df.iterrows():
        if row["type"] == "plan":
            geom = {
            "location":[row["latitude"], row["longitude"]],
            "tooltip" : row["name"]
            }
            
            if row["subtype"] == "restaurants":
                iconito = "cutlery"
            elif row["subtype"] == "leisure":
                iconito = "rocket"
            elif row["subtype"] == "outdoors":
                iconito = "pagelines"
            elif row["subtype"] == "snacks":
                iconito = "cutlery"
            elif row["subtype"] == "party":
                iconito = "glass"
            elif row["subtype"] == "drinks":
                iconito = "glass"
            else:
                iconito = "book"

            icon = Icon(color = "lightgreen",
                            prefix = "fa",
                            icon = iconito,
                            icon_color = "black"
            )

        elif row["type"] == "transport":
            geom = {
            "location":[row["latitude"], row["longitude"]],
            "tooltip" : row["place"]
            }

            if row["place"] == "bus":            
                icon = Icon(color = "lightblue",
                                prefix = "fa",
                                icon = "bus",
                                icon_color = "black"
                )   
            elif row["place"] == "train" or row["place"] == "metro":
                icon = Icon(color = "lightblue",
                                prefix = "fa",
                                icon = "train",
                                icon_color = "black"
                )
            else:
                icon = Icon(color = "lightblue",
                                prefix = "fa",
                                icon = "car",
                                icon_color = "black"
                ) 


        Marker(**geom,icon = icon ).add_to(map_1)
    return map_1

# %%
mapita(df,coordinates)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_a4a9746d67a848dcaef93c28891e612d%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_a4a9746d67a848dcaef93c28891e612d%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_a4a9746d67a848dcaef93c28891e612d%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_a4a9746d67a848dcaef93c28891e612d%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B40.49341%2C%20-3.69538%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %%
mapita(df,coordinates)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_e482e7407acc4c6191116bf15d841951%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_e482e7407acc4c6191116bf15d841951%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_e482e7407acc4c6191116bf15d841951%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_e482e7407acc4c6191116bf15d841951%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B40.49341%2C%20-3.69538%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %%
[2,24,3,35]+[34,4]
# Out:
# [2, 24, 3, 35, 34, 4]
